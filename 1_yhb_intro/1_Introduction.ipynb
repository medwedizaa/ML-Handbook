# %% [markdown]
# It is an example of working with a custom regressor and classifier. Also, there is an example of matrix usage for training with CatBoost.
#
# A data set I'm working with contains records about cafes, restaurants, and other facilities and their location, rating, average bill, categories, and features.
#
# The purpose of the training will be to predict the average bill.

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
work_dir = os.getcwd()
base = work_dir + '/'

data = pd.read_csv(base + 'organisations.csv')
features = pd.read_csv(base + 'features.csv')
rubrics = pd.read_csv(base + 'rubrics.csv')

# %%
data.head()
# Out:
#                  org_id city  average_bill    rating   rubrics_id  \
# 0  15903868628669802651  msk        1500.0  4.270968  30776 30774
# 1  16076540698036998306  msk         500.0  4.375000        30771
# 2   8129364761615040323  msk         500.0  4.000000        31495
# 3  15262729117594253452  msk         500.0  4.538813  30776 30770
# 4  13418544315327784420  msk         500.0  4.409091        31495
#
#                                          features_id
# 0  3501685156 3501779478 20422 3502045016 3502045...
# 1  1509 1082283206 273469383 10462 11617 35017794...
# 2  10462 11177 11617 11629 1416 1018 11704 11867 ...
# 3  3501618484 2020795524 11629 11617 1018 11704 2...
# 4  11617 10462 11177 1416 11867 3501744275 20282 ...

# %% [markdown]
# ### Data manipulation

# %%
rubric_dict = {}
for _, row in rubrics.iterrows():
    rubric_dict[row['rubric_id']] = row['rubric_name']
features_dict = {}
for _, row in features.iterrows():
    features_dict[row['feature_id']] = row['feature_name']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68339 entries, 0 to 68338
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   org_id        68339 non-null  uint64
#  1   city          68339 non-null  object
#  2   average_bill  32778 non-null  float64
#  3   rating        54608 non-null  float64
#  4   rubrics_id    68339 non-null  object
#  5   features_id   57290 non-null  object
# dtypes: float64(2), object(3), uint64(1)
# memory usage: 3.1+ MB

# %%
plt.hist(data['average_bill'])
plt.show()

# %%
plt.scatter(data['rating'], data['average_bill'])
plt.show()

# %%
sns.boxplot(data['average_bill'])
plt.show()

# %% [markdown]
# I'll remove the records with the average bill over 2500.

# %%
data_cleaned = data[~((data['average_bill'].isna()) | (data['average_bill'] > 2500))]
data_cleaned
# Out:
#                      org_id city  average_bill    rating         rubrics_id  \
# 0      15903868628669802651  msk        1500.0  4.270968        30776 30774
# 1      16076540698036998306  msk         500.0  4.375000              30771
# 2       8129364761615040323  msk         500.0  4.000000              31495
# 3      15262729117594253452  msk         500.0  4.538813        30776 30770
# 4      13418544315327784420  msk         500.0  4.409091              31495
# ...                     ...  ...           ...       ...                ...
# 68328  17662684569129497551  spb        1000.0  4.561707              30776
# 68329   5700899951016592061  msk        1500.0  4.377129              31401
# 68330   4686040819909966338  msk        1500.0  3.666667              30776
# 68331  12499715465202129892  msk        1500.0  4.554577  30770 30776 30774
# 68332    971801737399231340  msk        2500.0  4.659884              30776
#
#                                              features_id
# 0      3501685156 3501779478 20422 3502045016 3502045...
# 1      1509 1082283206 273469383 10462 11617 35017794...
# 2      10462 11177 11617 11629 1416 1018 11704 11867 ...
# 3      3501618484 2020795524 11629 11617 1018 11704 2...
# 4      11617 10462 11177 1416 11867 3501744275 20282 ...
# ...                                                  ...
# 68328  246 3501779478 1018 3501618484 3501481353 3501...
# 68329  3501773763 10462 1018 246 3501779478 350175479...
# 68330  10462 1189498238 11629 1416 1415 11741 3501481...
# 68331  273469383 10462 21247 1509 1416 3501618484 350...
# 68332  11629 10462 21247 20424 3501513153 273469383 3...
#
# [32136 rows x 6 columns]

# %% [markdown]
# ### Custom Regressor and Classificator

# %%
clean_data_train, clean_data_test = train_test_split(
    data_cleaned, stratify=data_cleaned['average_bill'], test_size=0.33, random_state=42)

# %%
from scipy.stats import mode
from sklearn.base import RegressorMixin
from sklearn.base import ClassifierMixin
import statistics
from warnings import simplefilter
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **There are two models:**
# * Regression model, which calculates the mean average bill among all the records.
# * Classification model, which predicts the one class - the most repeated one.

# %%
class MeanRegressor(RegressorMixin):
    # Predicts the mean of y_train
    def fit(self, X=None, y=None):
        self.y = np.mean(y)
        self.is_fitted_ = True
        return self

    def predict(self, X=None):
        return pd.Series([self.y] * len(X), index=X.index)

class MostFrequentClassifier(ClassifierMixin):
    def __init__(self):
        simplefilter(action='ignore', category=FutureWarning)
    # Predicts the rounded (just in case) median of y_train
    def fit(self, X=None, y=None): 
        d = {}
        for i in y:
            if i not in d:
                d[i] = 1
            else:
                d[i] = d[i] + 1
        self.classes_ = max(d, key=d.get)
        return self

    def predict(self, X=None):
        return pd.Series([self.classes_] * len(X), index=X.index)

# %%
reg = MeanRegressor()
reg.fit(y=clean_data_train['average_bill'])

clf = MostFrequentClassifier()
clf.fit(y=clean_data_train['average_bill'])

# %%
y_reg_pred = reg.predict(clean_data_test)
y_clf_pred = clf.predict(clean_data_test)

# %%
# а вот для классификационной можно найти обе метрики. Сделайте это. Какая модель оказалась лучше по RMSE?
rmse_reg = np.sqrt(mean_squared_error(clean_data_test['average_bill'], y_reg_pred))

rmse_clf = np.sqrt(mean_squared_error(clean_data_test['average_bill'], y_clf_pred))
bas_clf = balanced_accuracy_score(clean_data_test['average_bill'], y_clf_pred)

print(f"For regression model:\nRMSE: {rmse_reg}\n")
print(f"For classification model:\nRMSE: {rmse_clf}; Balanced accuracy score: {bas_clf}")
# Out:
# For regression model:
# RMSE: 448.7143889551622
#
# For classification model:
# RMSE: 514.7517402382093; Balanced accuracy score: 0.2

# %% [markdown]
# ______________________________________________________
# **More complicated model, which calculates the mean value for the city:**

# %%
class CityMeanRegressor(RegressorMixin):
    def fit(self, X=None, y=None):
        city_list = X['city']
        self.sity_means_ = pd.DataFrame({
            'city': city_list,
            'y': y
        }).groupby('city')['y'].mean().to_dict()
        return self

    def predict(self, X=None):
        return X['city'].map(self.sity_means_).values

# %%
X_train = clean_data_train.drop(['average_bill'], axis = 1)
y_train = clean_data_train['average_bill']
X_test = clean_data_test.drop(['average_bill'], axis = 1)
y_test = clean_data_test['average_bill']

model_city = CityMeanRegressor()
model_city.fit(X_train, y_train)

# %%
y_pred = model_city.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.2f}")
# Out:
# MAE: 345.30
# RMSE: 445.11
# R²: 0.02

# %% [markdown]
# -----
# **The next model calculates the median value of the average bill based on rubrics and city**
#
# But before, I'll create a new column in which will be the modified rubrics: it will be the current rubric or the value 'other' if the combination occurs in the dataset less than 100 times.

# %%
from collections import Counter

# %%
c = Counter(X_train['rubrics_id'])
X_train['modified_rubrics'] = X_train['rubrics_id'].apply(
    lambda x: x if c[x] >= 100 else 'other'
)
X_test['modified_rubrics'] = X_test['rubrics_id'].apply(
    lambda x: x if c[x] >= 100 else 'other'
)
X_test.head()
# Out:
#                      org_id city    rating         rubrics_id  \
# 65841  14385912302763770021  spb  4.748444  30776 30770 31401
# 48882  16695436192794975203  msk  3.793758              30771
# 33711  11841431940065207518  msk  3.606557        30771 30777
# 33544  16028521499441205186  msk  4.683841              30776
# 35293  12477116204055673498  spb  4.165394  30776 31401 30770
#
#                                              features_id modified_rubrics
# 65841  11177 3501618484 10462 3501481355 1509 1416 20...            other
# 48882  3501744275 273469383 3501513153 11617 10462 11...            30771
# 33711  3501773763 3501744275 3501773764 3501618484 15...            other
# 33544  3501618484 20422 1082283206 11704 11629 21247 ...            30776
# 35293  1524 246 11704 1018 3501618484 2020795524 2124...            other

# %%
class RubricCityMedianClassifier(ClassifierMixin):
    def __init__(self):
        simplefilter(action='ignore', category=FutureWarning)
    def fit(self, X=None, y=None):

        test = X
        test['y'] = y
        test_dict = {}
        result_dict = {}
        for item in test['city'].unique():
            test_dict[item] = test[test['city'] == item]

        for index in test_dict:
            result_dict[index] = test_dict[index].groupby(['modified_rubrics'])['y'].apply(
                lambda x: statistics.median(x)
            ).to_dict()
            
        self.classes_ = result_dict
        return self

    def predict(self, X=None):
        return X.apply(lambda x: (self.classes_[x['city']][x['modified_rubrics']]), axis=1)

# %%
model_rubric_city = RubricCityMedianClassifier()
model_rubric_city.fit(X_train, y_train)

# %%
y_pred = model_rubric_city.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
score = balanced_accuracy_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.2f}")
print(f"balanced_accuracy_score: {score:.2f}")
# Out:
# MAE: 193.02
# RMSE: 393.97
# R²: 0.23
# balanced_accuracy_score: 0.31

# %% [markdown]
# -----
# **This next model calculates the median value of the average bill based on rubrics and features**
#
# For this I'll create a modified feature column which contains rubrics and feature

# %%
def get_modified_features(feature):
    if feature in feature_set:
        return feature
    else:
        return "other"

X_train['modified_features'] = X_train['rubrics_id'] + "_" + X_train['features_id']

feature_set = set(X_train['modified_features'])

X_test['modified_features'] = X_test.apply(
    lambda x: get_modified_features(x['rubrics_id'] + "_" + x['features_id']), 
    axis = 1
)
X_train.head()
# Out:
#                      org_id city    rating   rubrics_id  \
# 45769   3276960721840719260  msk  4.500000        30770
# 39061   8452997364765928283  msk  4.442623  30774 30776
# 59281  14240408259222214074  spb  4.018868  30776 30774
# 51225  15114069072602161053  msk  4.364742  31401 30776
# 29587   2730337118800634815  msk  4.698718        30770
#
#                                              features_id modified_rubrics  \
# 45769            11704 20422 1018 11177 1416 11867 10462            30770
# 39061  1415 3501481355 1416 11629 10462 1524 20422 11...      30774 30776
# 59281  3502045032 11741 3502045016 10462 11704 350177...      30776 30774
# 51225  3501513153 3501779478 3491142672 273469383 350...            other
# 29587  21247 10896 3491142672 11629 3501481353 350148...            30770
#
#             y                                  modified_features
# 45769   500.0      30770_11704 20422 1018 11177 1416 11867 10462
# 39061  1500.0  30774 30776_1415 3501481355 1416 11629 10462 1...
# 59281  1000.0  30776 30774_3502045032 11741 3502045016 10462 ...
# 51225  1500.0  31401 30776_3501513153 3501779478 3491142672 2...
# 29587  1000.0  30770_21247 10896 3491142672 11629 3501481353 ...

# %%
class FeatureMedianClassifier(ClassifierMixin):
    
    def fit(self, X=None, y=None):
        self.medians_: dict = (
            X.assign(target=y).groupby('modified_features')
            ['target'].median().to_dict()  # Faster lookup than pandas series
        )
        self.medians_['other'] = y.median()

        return self

    def predict(self, X=None):
        return X['modified_features'].map(self.medians_)

# %%
model_features = FeatureMedianClassifier()
model_features.fit(X_train, y_train)
y_pred = model_features.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
score = balanced_accuracy_score(y_test, y_pred)

print(f"RMSE: {rmse:.2f}")
print(f"balanced_accuracy_score: {score:.2f}")
# Out:
# RMSE: 513.99
# balanced_accuracy_score: 0.20
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2480: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")

# %% [markdown]
# ### CatBoost and sparse matrix

# %% [markdown]
# For the CatBoost usage, I'll create columns for each rubric and feature from the train set, also I'll change the city columns' values: it will be 1 for 'msk' and 0 for 'spb'. After that, I'll create a COO matrix, which will be transformed into a CSR matrix.
# But before that I'll fill the missing values for rating

# %%
cleaned_data_withon_nan = data_cleaned
mean_rating = data_cleaned[~data_cleaned['rating'].isna()][['rating']].mean()
cleaned_data_withon_nan['rating'] = np.where(cleaned_data_withon_nan['rating'].isna(), mean_rating, cleaned_data_withon_nan['rating'])
cleaned_data_withon_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32136 entries, 0 to 68332
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   org_id        32136 non-null  uint64
#  1   city          32136 non-null  object
#  2   average_bill  32136 non-null  float64
#  3   rating        32136 non-null  float64
#  4   rubrics_id    32136 non-null  object
#  5   features_id   32136 non-null  object
# dtypes: float64(2), object(3), uint64(1)
# memory usage: 1.7+ MB
# /var/folders/1t/qjkxb95n6t340fwg3jkd9ltm0000gn/T/ipykernel_70675/3401320765.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data_withon_nan['rating'] = np.where(cleaned_data_withon_nan['rating'].isna(), mean_rating, cleaned_data_withon_nan['rating'])

# %%
clean_data_train, clean_data_test = train_test_split(
    cleaned_data_withon_nan, stratify=cleaned_data_withon_nan['average_bill'], test_size=0.33, random_state=42)
clean_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21531 entries, 45769 to 17863
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   org_id        21531 non-null  uint64
#  1   city          21531 non-null  object
#  2   average_bill  21531 non-null  float64
#  3   rating        21531 non-null  float64
#  4   rubrics_id    21531 non-null  object
#  5   features_id   21531 non-null  object
# dtypes: float64(2), object(3), uint64(1)
# memory usage: 1.1+ MB

# %%
clean_data_train['city'] = np.where(clean_data_train['city'] == 'msk', 1, 0)
clean_data_test['city'] = np.where(clean_data_test['city'] == 'msk', 1, 0)
clean_data_train.head()
# Out:
#                      org_id  city  average_bill    rating   rubrics_id  \
# 45769   3276960721840719260     1         500.0  4.500000        30770
# 39061   8452997364765928283     1        1500.0  4.442623  30774 30776
# 59281  14240408259222214074     0        1000.0  4.018868  30776 30774
# 51225  15114069072602161053     1        1500.0  4.364742  31401 30776
# 29587   2730337118800634815     1        1000.0  4.698718        30770
#
#                                              features_id
# 45769            11704 20422 1018 11177 1416 11867 10462
# 39061  1415 3501481355 1416 11629 10462 1524 20422 11...
# 59281  3502045032 11741 3502045016 10462 11704 350177...
# 51225  3501513153 3501779478 3491142672 273469383 350...
# 29587  21247 10896 3491142672 11629 3501481353 350148...

# %%
def get_unique_ids(series):
    return set(id_ for row in series for id_ in row.split())
    
# all unique rubrics and features from train
rubric_vocab = sorted(get_unique_ids(clean_data_train['rubrics_id']))
feature_vocab = sorted(get_unique_ids(clean_data_train['features_id']))

# create dictinaries: rubric -> column index
rubric_to_col = {rid: i for i, rid in enumerate(rubric_vocab)}
feature_to_col = {fid: i for i, fid in enumerate(feature_vocab)}

# %%
feature_names = ['rating', 'city']  

# add pubrics and features in the matrix's order
feature_names += [f"rubric_{rid}" for rid in rubric_vocab]
feature_names += [f"feature_{fid}" for fid in feature_vocab]

# the column for features from a test dataset, which didn't occur in the train
feature_names.append('feature_other')

# %%
rubric_to_col = {rid: i + 2 for i, rid in enumerate(rubric_vocab)}  # +2 из-за city и rating
feature_to_col = {fid: i + 2 + len(rubric_vocab) for i, fid in enumerate(feature_vocab)}
feature_to_col["feature_other"] = 2 + len(rubric_vocab) + len(feature_vocab)

n_cols = 2 + len(rubric_vocab) + len(feature_vocab) + 1

# %%
from scipy.sparse import coo_matrix

# %%
def build_sparse_matrix(df, rubric_to_col, feature_to_col, n_cols):
    row = []
    col = []
    data = []
    n_objects = df.shape[0]

    for i, row_data in enumerate(df.itertuples(index=False)):
        # city (0 or 1)
        row.append(i)
        col.append(0)
        data.append(row_data.city)

        # rating (the second column)
        row.append(i)
        col.append(1)
        data.append(row_data.rating)

        # rubrics
        for rid in row_data.rubrics_id.split():
            if rid in rubric_to_col:
                row.append(i)
                col.append(rubric_to_col[rid])
                data.append(1)

        # features
        unknown_feature_count = 0
        for fid in row_data.features_id.split():
            if fid in feature_to_col:
                row.append(i)
                col.append(feature_to_col[fid])
                data.append(1)
            else:
                unknown_feature_count += 1

        # feature_other — the number of unknown features
        if "feature_other" in feature_to_col:
            row.append(i)
            col.append(feature_to_col["feature_other"])
            data.append(unknown_feature_count)

    # build a COO-матрицу, and then transform into CSR
    sparse = coo_matrix((data, (row, col)), shape=(n_objects, n_cols)).tocsr()
    return sparse

# %%
sparse_data_train = build_sparse_matrix(clean_data_train, rubric_to_col, feature_to_col, n_cols)
sparse_data_test = build_sparse_matrix(clean_data_test, rubric_to_col, feature_to_col, n_cols)

# %%
from catboost import CatBoostClassifier

# %%
clf = CatBoostClassifier()
clf.fit(sparse_data_train, clean_data_train['average_bill'])
# Out:
# Learning rate set to 0.092536
# 0:	learn: 1.4298912	total: 93.9ms	remaining: 1m 33s
# 1:	learn: 1.3117349	total: 118ms	remaining: 58.9s
# 2:	learn: 1.2254349	total: 141ms	remaining: 47s
# 3:	learn: 1.1489528	total: 167ms	remaining: 41.6s
# 4:	learn: 1.0905690	total: 201ms	remaining: 39.9s
# 5:	learn: 1.0406406	total: 230ms	remaining: 38.1s
# 6:	learn: 1.0006546	total: 255ms	remaining: 36.1s
# 7:	learn: 0.9648913	total: 279ms	remaining: 34.6s
# 8:	learn: 0.9350792	total: 305ms	remaining: 33.5s
# 9:	learn: 0.9073672	total: 329ms	remaining: 32.6s
# 10:	learn: 0.8856449	total: 353ms	remaining: 31.8s
# 11:	learn: 0.8656296	total: 378ms	remaining: 31.1s
# 12:	learn: 0.8464786	total: 404ms	remaining: 30.6s
# 13:	learn: 0.8316937	total: 430ms	remaining: 30.3s
# 14:	learn: 0.8187064	total: 460ms	remaining: 30.2s
# 15:	learn: 0.8050988	total: 482ms	remaining: 29.7s
# 16:	learn: 0.7930401	total: 508ms	remaining: 29.4s
# 17:	learn: 0.7818719	total: 533ms	remaining: 29.1s
# 18:	learn: 0.7733504	total: 558ms	remaining: 28.8s
# 19:	learn: 0.7647236	total: 581ms	remaining: 28.5s
# 20:	learn: 0.7569426	total: 604ms	remaining: 28.2s
# 21:	learn: 0.7508869	total: 630ms	remaining: 28s
# 22:	learn: 0.7447207	total: 657ms	remaining: 27.9s
# 23:	learn: 0.7391279	total: 684ms	remaining: 27.8s
# 24:	learn: 0.7338356	total: 724ms	remaining: 28.2s
# 25:	learn: 0.7290746	total: 782ms	remaining: 29.3s
# 26:	learn: 0.7237647	total: 824ms	remaining: 29.7s
# 27:	learn: 0.7179872	total: 861ms	remaining: 29.9s
# 28:	learn: 0.7147836	total: 890ms	remaining: 29.8s
# 29:	learn: 0.7116140	total: 918ms	remaining: 29.7s
# 30:	learn: 0.7084209	total: 953ms	remaining: 29.8s
# 31:	learn: 0.7055806	total: 981ms	remaining: 29.7s
# 32:	learn: 0.7018951	total: 1s	remaining: 29.4s
# 33:	learn: 0.6985094	total: 1.03s	remaining: 29.3s
# 34:	learn: 0.6962343	total: 1.05s	remaining: 29s
# 35:	learn: 0.6921254	total: 1.08s	remaining: 28.9s
# 36:	learn: 0.6905704	total: 1.11s	remaining: 28.9s
# 37:	learn: 0.6883694	total: 1.14s	remaining: 28.8s
# 38:	learn: 0.6856284	total: 1.16s	remaining: 28.6s
# 39:	learn: 0.6834486	total: 1.18s	remaining: 28.4s
# 40:	learn: 0.6817518	total: 1.21s	remaining: 28.3s
# 41:	learn: 0.6807480	total: 1.23s	remaining: 28.1s
# 42:	learn: 0.6790474	total: 1.26s	remaining: 28s
# 43:	learn: 0.6780792	total: 1.28s	remaining: 27.9s
# 44:	learn: 0.6759866	total: 1.32s	remaining: 27.9s
# 45:	learn: 0.6737927	total: 1.34s	remaining: 27.9s
# 46:	learn: 0.6723304	total: 1.38s	remaining: 27.9s
# 47:	learn: 0.6710041	total: 1.41s	remaining: 27.9s
# 48:	learn: 0.6695352	total: 1.43s	remaining: 27.8s
# 49:	learn: 0.6684568	total: 1.46s	remaining: 27.7s
# 50:	learn: 0.6672738	total: 1.48s	remaining: 27.6s
# 51:	learn: 0.6660177	total: 1.51s	remaining: 27.5s
# 52:	learn: 0.6656733	total: 1.53s	remaining: 27.4s
# 53:	learn: 0.6643396	total: 1.57s	remaining: 27.5s
# 54:	learn: 0.6632052	total: 1.59s	remaining: 27.4s
# 55:	learn: 0.6623597	total: 1.62s	remaining: 27.3s
# 56:	learn: 0.6619908	total: 1.64s	remaining: 27.2s
# 57:	learn: 0.6602782	total: 1.67s	remaining: 27.1s
# 58:	learn: 0.6596738	total: 1.69s	remaining: 27s
# 59:	learn: 0.6594337	total: 1.72s	remaining: 27s
# 60:	learn: 0.6591242	total: 1.75s	remaining: 26.9s
# 61:	learn: 0.6578775	total: 1.78s	remaining: 26.9s
# 62:	learn: 0.6564114	total: 1.81s	remaining: 26.9s
# 63:	learn: 0.6556865	total: 1.84s	remaining: 26.9s
# 64:	learn: 0.6550474	total: 1.87s	remaining: 26.9s
# 65:	learn: 0.6542547	total: 1.9s	remaining: 26.8s
# 66:	learn: 0.6541471	total: 1.92s	remaining: 26.7s
# 67:	learn: 0.6534201	total: 1.95s	remaining: 26.8s
# 68:	learn: 0.6530529	total: 1.98s	remaining: 26.7s
# 69:	learn: 0.6528564	total: 2.01s	remaining: 26.7s
# 70:	learn: 0.6526327	total: 2.03s	remaining: 26.6s
# 71:	learn: 0.6521531	total: 2.06s	remaining: 26.5s
# 72:	learn: 0.6516281	total: 2.09s	remaining: 26.6s
# 73:	learn: 0.6514526	total: 2.13s	remaining: 26.6s
# 74:	learn: 0.6501983	total: 2.16s	remaining: 26.6s
# 75:	learn: 0.6501239	total: 2.2s	remaining: 26.8s
# 76:	learn: 0.6492411	total: 2.24s	remaining: 26.8s
# 77:	learn: 0.6489181	total: 2.27s	remaining: 26.8s
# 78:	learn: 0.6476301	total: 2.29s	remaining: 26.8s
# 79:	learn: 0.6473452	total: 2.32s	remaining: 26.7s
# 80:	learn: 0.6467928	total: 2.34s	remaining: 26.6s
# 81:	learn: 0.6464973	total: 2.36s	remaining: 26.5s
# 82:	learn: 0.6461317	total: 2.38s	remaining: 26.4s
# 83:	learn: 0.6452318	total: 2.41s	remaining: 26.3s
# 84:	learn: 0.6449890	total: 2.44s	remaining: 26.2s
# 85:	learn: 0.6440059	total: 2.47s	remaining: 26.2s
# 86:	learn: 0.6436414	total: 2.49s	remaining: 26.2s
# 87:	learn: 0.6429584	total: 2.52s	remaining: 26.1s
# 88:	learn: 0.6424904	total: 2.56s	remaining: 26.2s
# 89:	learn: 0.6420551	total: 2.59s	remaining: 26.2s
# 90:	learn: 0.6412159	total: 2.63s	remaining: 26.3s
# 91:	learn: 0.6411142	total: 2.66s	remaining: 26.3s
# 92:	learn: 0.6407228	total: 2.69s	remaining: 26.3s
# 93:	learn: 0.6400852	total: 2.73s	remaining: 26.3s
# 94:	learn: 0.6396538	total: 2.76s	remaining: 26.3s
# 95:	learn: 0.6395814	total: 2.78s	remaining: 26.2s
# 96:	learn: 0.6394119	total: 2.81s	remaining: 26.1s
# 97:	learn: 0.6393123	total: 2.83s	remaining: 26s
# 98:	learn: 0.6384794	total: 2.86s	remaining: 26s
# 99:	learn: 0.6380304	total: 2.91s	remaining: 26.2s
# 100:	learn: 0.6374763	total: 2.95s	remaining: 26.3s
# 101:	learn: 0.6374120	total: 2.99s	remaining: 26.3s
# 102:	learn: 0.6367543	total: 3.02s	remaining: 26.3s
# 103:	learn: 0.6361640	total: 3.06s	remaining: 26.3s
# 104:	learn: 0.6358640	total: 3.08s	remaining: 26.3s
# 105:	learn: 0.6352886	total: 3.11s	remaining: 26.2s
# 106:	learn: 0.6351208	total: 3.14s	remaining: 26.2s
# 107:	learn: 0.6344747	total: 3.17s	remaining: 26.2s
# 108:	learn: 0.6339748	total: 3.19s	remaining: 26.1s
# 109:	learn: 0.6337082	total: 3.22s	remaining: 26s
# 110:	learn: 0.6336266	total: 3.24s	remaining: 26s
# 111:	learn: 0.6325771	total: 3.28s	remaining: 26s
# 112:	learn: 0.6322664	total: 3.32s	remaining: 26.1s
# 113:	learn: 0.6316097	total: 3.35s	remaining: 26.1s
# 114:	learn: 0.6313391	total: 3.39s	remaining: 26.1s
# 115:	learn: 0.6306053	total: 3.41s	remaining: 26s
# 116:	learn: 0.6304712	total: 3.44s	remaining: 26s
# 117:	learn: 0.6300163	total: 3.48s	remaining: 26s
# 118:	learn: 0.6297506	total: 3.51s	remaining: 26s
# 119:	learn: 0.6293226	total: 3.54s	remaining: 26s
# 120:	learn: 0.6292465	total: 3.57s	remaining: 25.9s
# 121:	learn: 0.6291429	total: 3.62s	remaining: 26.1s
# 122:	learn: 0.6286985	total: 3.65s	remaining: 26s
# 123:	learn: 0.6285160	total: 3.67s	remaining: 25.9s
# 124:	learn: 0.6283141	total: 3.69s	remaining: 25.9s
# 125:	learn: 0.6281894	total: 3.71s	remaining: 25.8s
# 126:	learn: 0.6277032	total: 3.74s	remaining: 25.7s
# 127:	learn: 0.6272021	total: 3.76s	remaining: 25.6s
# 128:	learn: 0.6269842	total: 3.78s	remaining: 25.6s
# 129:	learn: 0.6264693	total: 3.81s	remaining: 25.5s
# 130:	learn: 0.6263778	total: 3.83s	remaining: 25.4s
# 131:	learn: 0.6262154	total: 3.85s	remaining: 25.3s
# 132:	learn: 0.6261505	total: 3.87s	remaining: 25.2s
# 133:	learn: 0.6260287	total: 3.89s	remaining: 25.2s
# 134:	learn: 0.6256541	total: 3.92s	remaining: 25.1s
# 135:	learn: 0.6254629	total: 3.94s	remaining: 25s
# 136:	learn: 0.6254090	total: 3.96s	remaining: 24.9s
# 137:	learn: 0.6253290	total: 3.98s	remaining: 24.9s
# 138:	learn: 0.6248241	total: 4s	remaining: 24.8s
# 139:	learn: 0.6242837	total: 4.03s	remaining: 24.8s
# 140:	learn: 0.6238832	total: 4.06s	remaining: 24.7s
# 141:	learn: 0.6236568	total: 4.08s	remaining: 24.6s
# 142:	learn: 0.6235672	total: 4.1s	remaining: 24.6s
# 143:	learn: 0.6232449	total: 4.12s	remaining: 24.5s
# 144:	learn: 0.6223725	total: 4.15s	remaining: 24.5s
# 145:	learn: 0.6221842	total: 4.17s	remaining: 24.4s
# 146:	learn: 0.6217970	total: 4.21s	remaining: 24.4s
# 147:	learn: 0.6215150	total: 4.25s	remaining: 24.5s
# 148:	learn: 0.6213853	total: 4.29s	remaining: 24.5s
# 149:	learn: 0.6212660	total: 4.32s	remaining: 24.5s
# 150:	learn: 0.6205837	total: 4.34s	remaining: 24.4s
# 151:	learn: 0.6198407	total: 4.37s	remaining: 24.4s
# 152:	learn: 0.6195572	total: 4.39s	remaining: 24.3s
# 153:	learn: 0.6187070	total: 4.42s	remaining: 24.3s
# 154:	learn: 0.6184955	total: 4.44s	remaining: 24.2s
# 155:	learn: 0.6183236	total: 4.46s	remaining: 24.1s
# 156:	learn: 0.6178065	total: 4.48s	remaining: 24.1s
# 157:	learn: 0.6169557	total: 4.51s	remaining: 24s
# 158:	learn: 0.6164601	total: 4.53s	remaining: 24s
# 159:	learn: 0.6163534	total: 4.56s	remaining: 23.9s
# 160:	learn: 0.6160493	total: 4.58s	remaining: 23.9s
# 161:	learn: 0.6159308	total: 4.6s	remaining: 23.8s
# 162:	learn: 0.6155988	total: 4.62s	remaining: 23.7s
# 163:	learn: 0.6154297	total: 4.64s	remaining: 23.7s
# 164:	learn: 0.6153700	total: 4.66s	remaining: 23.6s
# 165:	learn: 0.6148886	total: 4.68s	remaining: 23.5s
# 166:	learn: 0.6145105	total: 4.71s	remaining: 23.5s
# 167:	learn: 0.6143964	total: 4.73s	remaining: 23.4s
# 168:	learn: 0.6140230	total: 4.75s	remaining: 23.4s
# 169:	learn: 0.6137830	total: 4.78s	remaining: 23.3s
# 170:	learn: 0.6136009	total: 4.8s	remaining: 23.3s
# 171:	learn: 0.6134105	total: 4.82s	remaining: 23.2s
# 172:	learn: 0.6132867	total: 4.84s	remaining: 23.1s
# 173:	learn: 0.6130022	total: 4.87s	remaining: 23.1s
# 174:	learn: 0.6124868	total: 4.89s	remaining: 23s
# 175:	learn: 0.6120124	total: 4.91s	remaining: 23s
# 176:	learn: 0.6119255	total: 4.93s	remaining: 22.9s
# 177:	learn: 0.6114694	total: 4.96s	remaining: 22.9s
# 178:	learn: 0.6113516	total: 4.98s	remaining: 22.8s
# 179:	learn: 0.6109737	total: 5s	remaining: 22.8s
# 180:	learn: 0.6105293	total: 5.02s	remaining: 22.7s
# 181:	learn: 0.6098984	total: 5.05s	remaining: 22.7s
# 182:	learn: 0.6097242	total: 5.07s	remaining: 22.6s
# 183:	learn: 0.6093756	total: 5.09s	remaining: 22.6s
# 184:	learn: 0.6088017	total: 5.12s	remaining: 22.5s
# 185:	learn: 0.6082462	total: 5.14s	remaining: 22.5s
# 186:	learn: 0.6077027	total: 5.17s	remaining: 22.5s
# 187:	learn: 0.6070078	total: 5.19s	remaining: 22.4s
# 188:	learn: 0.6069209	total: 5.21s	remaining: 22.4s
# 189:	learn: 0.6068379	total: 5.23s	remaining: 22.3s
# 190:	learn: 0.6066004	total: 5.25s	remaining: 22.3s
# 191:	learn: 0.6063289	total: 5.28s	remaining: 22.2s
# 192:	learn: 0.6057958	total: 5.3s	remaining: 22.2s
# 193:	learn: 0.6055967	total: 5.32s	remaining: 22.1s
# 194:	learn: 0.6052538	total: 5.35s	remaining: 22.1s
# 195:	learn: 0.6051860	total: 5.37s	remaining: 22s
# 196:	learn: 0.6049173	total: 5.39s	remaining: 22s
# 197:	learn: 0.6048956	total: 5.41s	remaining: 21.9s
# 198:	learn: 0.6046883	total: 5.43s	remaining: 21.9s
# 199:	learn: 0.6046591	total: 5.45s	remaining: 21.8s
# 200:	learn: 0.6045099	total: 5.47s	remaining: 21.8s
# 201:	learn: 0.6043413	total: 5.5s	remaining: 21.7s
# 202:	learn: 0.6038796	total: 5.52s	remaining: 21.7s
# 203:	learn: 0.6035735	total: 5.55s	remaining: 21.6s
# 204:	learn: 0.6033023	total: 5.57s	remaining: 21.6s
# 205:	learn: 0.6030084	total: 5.59s	remaining: 21.6s
# 206:	learn: 0.6028913	total: 5.62s	remaining: 21.5s
# 207:	learn: 0.6023665	total: 5.64s	remaining: 21.5s
# 208:	learn: 0.6022468	total: 5.66s	remaining: 21.4s
# 209:	learn: 0.6019287	total: 5.68s	remaining: 21.4s
# 210:	learn: 0.6018327	total: 5.7s	remaining: 21.3s
# 211:	learn: 0.6013791	total: 5.72s	remaining: 21.3s
# 212:	learn: 0.6012017	total: 5.75s	remaining: 21.2s
# 213:	learn: 0.6010488	total: 5.77s	remaining: 21.2s
# 214:	learn: 0.6008631	total: 5.79s	remaining: 21.1s
# 215:	learn: 0.6006737	total: 5.81s	remaining: 21.1s
# 216:	learn: 0.6004725	total: 5.83s	remaining: 21.1s
# 217:	learn: 0.6000060	total: 5.86s	remaining: 21s
# 218:	learn: 0.5999495	total: 5.88s	remaining: 21s
# 219:	learn: 0.5998797	total: 5.91s	remaining: 20.9s
# 220:	learn: 0.5997306	total: 5.93s	remaining: 20.9s
# 221:	learn: 0.5993978	total: 5.96s	remaining: 20.9s
# 222:	learn: 0.5993645	total: 5.98s	remaining: 20.8s
# 223:	learn: 0.5987357	total: 6s	remaining: 20.8s
# 224:	learn: 0.5987121	total: 6.03s	remaining: 20.8s
# 225:	learn: 0.5982540	total: 6.05s	remaining: 20.7s
# 226:	learn: 0.5978465	total: 6.07s	remaining: 20.7s
# 227:	learn: 0.5976848	total: 6.1s	remaining: 20.6s
# 228:	learn: 0.5976420	total: 6.12s	remaining: 20.6s
# 229:	learn: 0.5971525	total: 6.14s	remaining: 20.6s
# 230:	learn: 0.5969159	total: 6.16s	remaining: 20.5s
# 231:	learn: 0.5966379	total: 6.19s	remaining: 20.5s
# 232:	learn: 0.5965777	total: 6.21s	remaining: 20.4s
# 233:	learn: 0.5964714	total: 6.23s	remaining: 20.4s
# 234:	learn: 0.5960214	total: 6.25s	remaining: 20.4s
# 235:	learn: 0.5958062	total: 6.28s	remaining: 20.3s
# 236:	learn: 0.5956768	total: 6.3s	remaining: 20.3s
# 237:	learn: 0.5955385	total: 6.32s	remaining: 20.2s
# 238:	learn: 0.5953802	total: 6.34s	remaining: 20.2s
# 239:	learn: 0.5953291	total: 6.36s	remaining: 20.1s
# 240:	learn: 0.5953072	total: 6.38s	remaining: 20.1s
# 241:	learn: 0.5951833	total: 6.41s	remaining: 20.1s
# 242:	learn: 0.5950391	total: 6.44s	remaining: 20.1s
# 243:	learn: 0.5949802	total: 6.47s	remaining: 20s
# 244:	learn: 0.5948075	total: 6.49s	remaining: 20s
# 245:	learn: 0.5944947	total: 6.52s	remaining: 20s
# 246:	learn: 0.5942917	total: 6.56s	remaining: 20s
# 247:	learn: 0.5939725	total: 6.59s	remaining: 20s
# 248:	learn: 0.5938592	total: 6.61s	remaining: 19.9s
# 249:	learn: 0.5937745	total: 6.64s	remaining: 19.9s
# 250:	learn: 0.5936252	total: 6.66s	remaining: 19.9s
# 251:	learn: 0.5933680	total: 6.69s	remaining: 19.8s
# 252:	learn: 0.5933387	total: 6.71s	remaining: 19.8s
# 253:	learn: 0.5928852	total: 6.73s	remaining: 19.8s
# 254:	learn: 0.5928062	total: 6.76s	remaining: 19.7s
# 255:	learn: 0.5923431	total: 6.78s	remaining: 19.7s
# 256:	learn: 0.5923098	total: 6.81s	remaining: 19.7s
# 257:	learn: 0.5922937	total: 6.83s	remaining: 19.7s
# 258:	learn: 0.5921393	total: 6.86s	remaining: 19.6s
# 259:	learn: 0.5921213	total: 6.88s	remaining: 19.6s
# 260:	learn: 0.5918532	total: 6.92s	remaining: 19.6s
# 261:	learn: 0.5917074	total: 6.95s	remaining: 19.6s
# 262:	learn: 0.5916860	total: 6.99s	remaining: 19.6s
# 263:	learn: 0.5916512	total: 7.01s	remaining: 19.6s
# 264:	learn: 0.5913853	total: 7.04s	remaining: 19.5s
# 265:	learn: 0.5912616	total: 7.07s	remaining: 19.5s
# 266:	learn: 0.5909657	total: 7.11s	remaining: 19.5s
# 267:	learn: 0.5908901	total: 7.13s	remaining: 19.5s
# 268:	learn: 0.5907881	total: 7.16s	remaining: 19.5s
# 269:	learn: 0.5905476	total: 7.18s	remaining: 19.4s
# 270:	learn: 0.5904545	total: 7.2s	remaining: 19.4s
# 271:	learn: 0.5903579	total: 7.23s	remaining: 19.4s
# 272:	learn: 0.5901279	total: 7.26s	remaining: 19.3s
# 273:	learn: 0.5899183	total: 7.3s	remaining: 19.3s
# 274:	learn: 0.5896502	total: 7.35s	remaining: 19.4s
# 275:	learn: 0.5893652	total: 7.38s	remaining: 19.4s
# 276:	learn: 0.5892061	total: 7.41s	remaining: 19.3s
# 277:	learn: 0.5889268	total: 7.43s	remaining: 19.3s
# 278:	learn: 0.5886303	total: 7.47s	remaining: 19.3s
# 279:	learn: 0.5885746	total: 7.51s	remaining: 19.3s
# 280:	learn: 0.5882118	total: 7.56s	remaining: 19.3s
# 281:	learn: 0.5880751	total: 7.6s	remaining: 19.3s
# 282:	learn: 0.5879925	total: 7.63s	remaining: 19.3s
# 283:	learn: 0.5879274	total: 7.67s	remaining: 19.3s
# 284:	learn: 0.5877131	total: 7.72s	remaining: 19.4s
# 285:	learn: 0.5873091	total: 7.74s	remaining: 19.3s
# 286:	learn: 0.5872404	total: 7.76s	remaining: 19.3s
# 287:	learn: 0.5871788	total: 7.79s	remaining: 19.3s
# 288:	learn: 0.5871215	total: 7.81s	remaining: 19.2s
# 289:	learn: 0.5869769	total: 7.83s	remaining: 19.2s
# 290:	learn: 0.5866185	total: 7.86s	remaining: 19.2s
# 291:	learn: 0.5865830	total: 7.9s	remaining: 19.1s
# 292:	learn: 0.5864952	total: 7.92s	remaining: 19.1s
# 293:	learn: 0.5864582	total: 7.94s	remaining: 19.1s
# 294:	learn: 0.5861779	total: 7.96s	remaining: 19s
# 295:	learn: 0.5858305	total: 7.99s	remaining: 19s
# 296:	learn: 0.5854030	total: 8.01s	remaining: 19s
# 297:	learn: 0.5853884	total: 8.03s	remaining: 18.9s
# 298:	learn: 0.5853439	total: 8.05s	remaining: 18.9s
# 299:	learn: 0.5853343	total: 8.07s	remaining: 18.8s
# 300:	learn: 0.5849379	total: 8.1s	remaining: 18.8s
# 301:	learn: 0.5848695	total: 8.12s	remaining: 18.8s
# 302:	learn: 0.5847581	total: 8.14s	remaining: 18.7s
# 303:	learn: 0.5847100	total: 8.17s	remaining: 18.7s
# 304:	learn: 0.5846846	total: 8.19s	remaining: 18.7s
# 305:	learn: 0.5846261	total: 8.21s	remaining: 18.6s
# 306:	learn: 0.5844562	total: 8.24s	remaining: 18.6s
# 307:	learn: 0.5844128	total: 8.27s	remaining: 18.6s
# 308:	learn: 0.5843788	total: 8.3s	remaining: 18.6s
# 309:	learn: 0.5843358	total: 8.32s	remaining: 18.5s
# 310:	learn: 0.5836359	total: 8.36s	remaining: 18.5s
# 311:	learn: 0.5835490	total: 8.39s	remaining: 18.5s
# 312:	learn: 0.5832577	total: 8.42s	remaining: 18.5s
# 313:	learn: 0.5830713	total: 8.45s	remaining: 18.5s
# 314:	learn: 0.5829741	total: 8.48s	remaining: 18.4s
# 315:	learn: 0.5829046	total: 8.5s	remaining: 18.4s
# 316:	learn: 0.5828774	total: 8.52s	remaining: 18.4s
# 317:	learn: 0.5827713	total: 8.55s	remaining: 18.3s
# 318:	learn: 0.5822705	total: 8.57s	remaining: 18.3s
# 319:	learn: 0.5821221	total: 8.6s	remaining: 18.3s
# 320:	learn: 0.5820250	total: 8.62s	remaining: 18.2s
# 321:	learn: 0.5818794	total: 8.65s	remaining: 18.2s
# 322:	learn: 0.5816339	total: 8.67s	remaining: 18.2s
# 323:	learn: 0.5813889	total: 8.7s	remaining: 18.2s
# 324:	learn: 0.5811129	total: 8.73s	remaining: 18.1s
# 325:	learn: 0.5810896	total: 8.76s	remaining: 18.1s
# 326:	learn: 0.5810197	total: 8.78s	remaining: 18.1s
# 327:	learn: 0.5809674	total: 8.8s	remaining: 18s
# 328:	learn: 0.5808003	total: 8.82s	remaining: 18s
# 329:	learn: 0.5807372	total: 8.86s	remaining: 18s
# 330:	learn: 0.5805464	total: 8.89s	remaining: 18s
# 331:	learn: 0.5803157	total: 8.92s	remaining: 17.9s
# 332:	learn: 0.5802469	total: 8.94s	remaining: 17.9s
# 333:	learn: 0.5801176	total: 8.96s	remaining: 17.9s
# 334:	learn: 0.5800444	total: 8.99s	remaining: 17.8s
# 335:	learn: 0.5800007	total: 9.01s	remaining: 17.8s
# 336:	learn: 0.5799367	total: 9.04s	remaining: 17.8s
# 337:	learn: 0.5797395	total: 9.06s	remaining: 17.8s
# 338:	learn: 0.5796738	total: 9.09s	remaining: 17.7s
# 339:	learn: 0.5795039	total: 9.11s	remaining: 17.7s
# 340:	learn: 0.5794106	total: 9.13s	remaining: 17.6s
# 341:	learn: 0.5793133	total: 9.15s	remaining: 17.6s
# 342:	learn: 0.5791866	total: 9.18s	remaining: 17.6s
# 343:	learn: 0.5788974	total: 9.21s	remaining: 17.6s
# 344:	learn: 0.5788061	total: 9.23s	remaining: 17.5s
# 345:	learn: 0.5786992	total: 9.26s	remaining: 17.5s
# 346:	learn: 0.5786029	total: 9.28s	remaining: 17.5s
# 347:	learn: 0.5782803	total: 9.31s	remaining: 17.4s
# 348:	learn: 0.5781432	total: 9.33s	remaining: 17.4s
# 349:	learn: 0.5781216	total: 9.36s	remaining: 17.4s
# 350:	learn: 0.5779682	total: 9.38s	remaining: 17.3s
# 351:	learn: 0.5778716	total: 9.42s	remaining: 17.3s
# 352:	learn: 0.5778394	total: 9.45s	remaining: 17.3s
# 353:	learn: 0.5778124	total: 9.47s	remaining: 17.3s
# 354:	learn: 0.5775919	total: 9.5s	remaining: 17.3s
# 355:	learn: 0.5774354	total: 9.53s	remaining: 17.2s
# 356:	learn: 0.5771380	total: 9.55s	remaining: 17.2s
# 357:	learn: 0.5769003	total: 9.58s	remaining: 17.2s
# 358:	learn: 0.5765710	total: 9.62s	remaining: 17.2s
# 359:	learn: 0.5764785	total: 9.65s	remaining: 17.2s
# 360:	learn: 0.5762824	total: 9.68s	remaining: 17.1s
# 361:	learn: 0.5760558	total: 9.7s	remaining: 17.1s
# 362:	learn: 0.5760360	total: 9.72s	remaining: 17.1s
# 363:	learn: 0.5758427	total: 9.74s	remaining: 17s
# 364:	learn: 0.5758159	total: 9.76s	remaining: 17s
# 365:	learn: 0.5757614	total: 9.78s	remaining: 16.9s
# 366:	learn: 0.5755932	total: 9.81s	remaining: 16.9s
# 367:	learn: 0.5754727	total: 9.83s	remaining: 16.9s
# 368:	learn: 0.5752456	total: 9.85s	remaining: 16.8s
# 369:	learn: 0.5749979	total: 9.88s	remaining: 16.8s
# 370:	learn: 0.5747238	total: 9.91s	remaining: 16.8s
# 371:	learn: 0.5745832	total: 9.94s	remaining: 16.8s
# 372:	learn: 0.5745519	total: 9.96s	remaining: 16.7s
# 373:	learn: 0.5744526	total: 9.98s	remaining: 16.7s
# 374:	learn: 0.5742648	total: 10s	remaining: 16.7s
# 375:	learn: 0.5740764	total: 10s	remaining: 16.6s
# 376:	learn: 0.5738424	total: 10.1s	remaining: 16.6s
# 377:	learn: 0.5738046	total: 10.1s	remaining: 16.6s
# 378:	learn: 0.5734446	total: 10.1s	remaining: 16.6s
# 379:	learn: 0.5734361	total: 10.1s	remaining: 16.5s
# 380:	learn: 0.5733068	total: 10.1s	remaining: 16.5s
# 381:	learn: 0.5731532	total: 10.2s	remaining: 16.5s
# 382:	learn: 0.5730102	total: 10.2s	remaining: 16.4s
# 383:	learn: 0.5727583	total: 10.2s	remaining: 16.4s
# 384:	learn: 0.5725632	total: 10.3s	remaining: 16.4s
# 385:	learn: 0.5723633	total: 10.3s	remaining: 16.4s
# 386:	learn: 0.5723365	total: 10.3s	remaining: 16.3s
# 387:	learn: 0.5719967	total: 10.3s	remaining: 16.3s
# 388:	learn: 0.5719861	total: 10.4s	remaining: 16.3s
# 389:	learn: 0.5717158	total: 10.4s	remaining: 16.2s
# 390:	learn: 0.5715134	total: 10.4s	remaining: 16.2s
# 391:	learn: 0.5715004	total: 10.4s	remaining: 16.2s
# 392:	learn: 0.5714493	total: 10.5s	remaining: 16.2s
# 393:	learn: 0.5712493	total: 10.5s	remaining: 16.1s
# 394:	learn: 0.5712012	total: 10.5s	remaining: 16.1s
# 395:	learn: 0.5708257	total: 10.5s	remaining: 16.1s
# 396:	learn: 0.5707875	total: 10.6s	remaining: 16s
# 397:	learn: 0.5704968	total: 10.6s	remaining: 16s
# 398:	learn: 0.5704206	total: 10.6s	remaining: 16s
# 399:	learn: 0.5703116	total: 10.7s	remaining: 16s
# 400:	learn: 0.5702100	total: 10.7s	remaining: 16s
# 401:	learn: 0.5700823	total: 10.7s	remaining: 15.9s
# 402:	learn: 0.5699214	total: 10.7s	remaining: 15.9s
# 403:	learn: 0.5699074	total: 10.7s	remaining: 15.9s
# 404:	learn: 0.5698890	total: 10.8s	remaining: 15.8s
# 405:	learn: 0.5698574	total: 10.8s	remaining: 15.8s
# 406:	learn: 0.5697615	total: 10.8s	remaining: 15.8s
# 407:	learn: 0.5695816	total: 10.8s	remaining: 15.7s
# 408:	learn: 0.5693684	total: 10.9s	remaining: 15.7s
# 409:	learn: 0.5692887	total: 10.9s	remaining: 15.7s
# 410:	learn: 0.5692404	total: 10.9s	remaining: 15.6s
# 411:	learn: 0.5691615	total: 10.9s	remaining: 15.6s
# 412:	learn: 0.5689728	total: 11s	remaining: 15.6s
# 413:	learn: 0.5688800	total: 11s	remaining: 15.5s
# 414:	learn: 0.5687825	total: 11s	remaining: 15.5s
# 415:	learn: 0.5686031	total: 11s	remaining: 15.5s
# 416:	learn: 0.5682314	total: 11.1s	remaining: 15.5s
# 417:	learn: 0.5681392	total: 11.1s	remaining: 15.4s
# 418:	learn: 0.5680052	total: 11.1s	remaining: 15.4s
# 419:	learn: 0.5678966	total: 11.1s	remaining: 15.4s
# 420:	learn: 0.5675929	total: 11.2s	remaining: 15.4s
# 421:	learn: 0.5675319	total: 11.2s	remaining: 15.3s
# 422:	learn: 0.5675131	total: 11.2s	remaining: 15.3s
# 423:	learn: 0.5673506	total: 11.3s	remaining: 15.3s
# 424:	learn: 0.5672829	total: 11.3s	remaining: 15.3s
# 425:	learn: 0.5671848	total: 11.3s	remaining: 15.2s
# 426:	learn: 0.5671668	total: 11.3s	remaining: 15.2s
# 427:	learn: 0.5670826	total: 11.4s	remaining: 15.2s
# 428:	learn: 0.5668039	total: 11.4s	remaining: 15.1s
# 429:	learn: 0.5667495	total: 11.4s	remaining: 15.1s
# 430:	learn: 0.5667100	total: 11.4s	remaining: 15.1s
# 431:	learn: 0.5666198	total: 11.4s	remaining: 15.1s
# 432:	learn: 0.5665381	total: 11.5s	remaining: 15s
# 433:	learn: 0.5664799	total: 11.5s	remaining: 15s
# 434:	learn: 0.5664054	total: 11.5s	remaining: 15s
# 435:	learn: 0.5663781	total: 11.6s	remaining: 15s
# 436:	learn: 0.5663503	total: 11.6s	remaining: 14.9s
# 437:	learn: 0.5663199	total: 11.6s	remaining: 14.9s
# 438:	learn: 0.5661862	total: 11.6s	remaining: 14.9s
# 439:	learn: 0.5660924	total: 11.7s	remaining: 14.8s
# 440:	learn: 0.5660642	total: 11.7s	remaining: 14.8s
# 441:	learn: 0.5658255	total: 11.7s	remaining: 14.8s
# 442:	learn: 0.5657140	total: 11.7s	remaining: 14.8s
# 443:	learn: 0.5654235	total: 11.8s	remaining: 14.7s
# 444:	learn: 0.5653811	total: 11.8s	remaining: 14.7s
# 445:	learn: 0.5651421	total: 11.8s	remaining: 14.7s
# 446:	learn: 0.5650301	total: 11.8s	remaining: 14.6s
# 447:	learn: 0.5649164	total: 11.9s	remaining: 14.6s
# 448:	learn: 0.5648400	total: 11.9s	remaining: 14.6s
# 449:	learn: 0.5648250	total: 11.9s	remaining: 14.5s
# 450:	learn: 0.5647584	total: 11.9s	remaining: 14.5s
# 451:	learn: 0.5646474	total: 11.9s	remaining: 14.5s
# 452:	learn: 0.5646166	total: 12s	remaining: 14.5s
# 453:	learn: 0.5645584	total: 12s	remaining: 14.4s
# 454:	learn: 0.5643305	total: 12.1s	remaining: 14.4s
# 455:	learn: 0.5642448	total: 12.1s	remaining: 14.4s
# 456:	learn: 0.5641777	total: 12.1s	remaining: 14.4s
# 457:	learn: 0.5640462	total: 12.1s	remaining: 14.4s
# 458:	learn: 0.5638496	total: 12.2s	remaining: 14.3s
# 459:	learn: 0.5637427	total: 12.2s	remaining: 14.3s
# 460:	learn: 0.5636588	total: 12.2s	remaining: 14.3s
# 461:	learn: 0.5636145	total: 12.2s	remaining: 14.2s
# 462:	learn: 0.5633090	total: 12.2s	remaining: 14.2s
# 463:	learn: 0.5632132	total: 12.3s	remaining: 14.2s
# 464:	learn: 0.5629547	total: 12.3s	remaining: 14.1s
# 465:	learn: 0.5628638	total: 12.3s	remaining: 14.1s
# 466:	learn: 0.5626283	total: 12.3s	remaining: 14.1s
# 467:	learn: 0.5625204	total: 12.4s	remaining: 14.1s
# 468:	learn: 0.5622520	total: 12.4s	remaining: 14s
# 469:	learn: 0.5622246	total: 12.4s	remaining: 14s
# 470:	learn: 0.5621926	total: 12.4s	remaining: 14s
# 471:	learn: 0.5620696	total: 12.5s	remaining: 13.9s
# 472:	learn: 0.5618709	total: 12.5s	remaining: 13.9s
# 473:	learn: 0.5616239	total: 12.5s	remaining: 13.9s
# 474:	learn: 0.5615206	total: 12.5s	remaining: 13.9s
# 475:	learn: 0.5614519	total: 12.6s	remaining: 13.8s
# 476:	learn: 0.5614048	total: 12.6s	remaining: 13.8s
# 477:	learn: 0.5613490	total: 12.6s	remaining: 13.8s
# 478:	learn: 0.5612053	total: 12.6s	remaining: 13.7s
# 479:	learn: 0.5610461	total: 12.7s	remaining: 13.7s
# 480:	learn: 0.5607820	total: 12.7s	remaining: 13.7s
# 481:	learn: 0.5604029	total: 12.7s	remaining: 13.7s
# 482:	learn: 0.5602280	total: 12.7s	remaining: 13.6s
# 483:	learn: 0.5600491	total: 12.8s	remaining: 13.6s
# 484:	learn: 0.5599103	total: 12.8s	remaining: 13.6s
# 485:	learn: 0.5598152	total: 12.8s	remaining: 13.5s
# 486:	learn: 0.5598019	total: 12.8s	remaining: 13.5s
# 487:	learn: 0.5597761	total: 12.8s	remaining: 13.5s
# 488:	learn: 0.5597296	total: 12.9s	remaining: 13.4s
# 489:	learn: 0.5596200	total: 12.9s	remaining: 13.4s
# 490:	learn: 0.5594968	total: 12.9s	remaining: 13.4s
# 491:	learn: 0.5594360	total: 12.9s	remaining: 13.4s
# 492:	learn: 0.5592376	total: 13s	remaining: 13.3s
# 493:	learn: 0.5591407	total: 13s	remaining: 13.3s
# 494:	learn: 0.5591056	total: 13s	remaining: 13.3s
# 495:	learn: 0.5588371	total: 13s	remaining: 13.2s
# 496:	learn: 0.5588071	total: 13.1s	remaining: 13.2s
# 497:	learn: 0.5586205	total: 13.1s	remaining: 13.2s
# 498:	learn: 0.5585995	total: 13.1s	remaining: 13.2s
# 499:	learn: 0.5584464	total: 13.1s	remaining: 13.1s
# 500:	learn: 0.5583216	total: 13.2s	remaining: 13.1s
# 501:	learn: 0.5582394	total: 13.2s	remaining: 13.1s
# 502:	learn: 0.5582247	total: 13.2s	remaining: 13s
# 503:	learn: 0.5581804	total: 13.2s	remaining: 13s
# 504:	learn: 0.5581575	total: 13.2s	remaining: 13s
# 505:	learn: 0.5581047	total: 13.3s	remaining: 12.9s
# 506:	learn: 0.5580926	total: 13.3s	remaining: 12.9s
# 507:	learn: 0.5579463	total: 13.3s	remaining: 12.9s
# 508:	learn: 0.5579235	total: 13.3s	remaining: 12.9s
# 509:	learn: 0.5578822	total: 13.4s	remaining: 12.8s
# 510:	learn: 0.5578622	total: 13.4s	remaining: 12.8s
# 511:	learn: 0.5576160	total: 13.4s	remaining: 12.8s
# 512:	learn: 0.5574819	total: 13.4s	remaining: 12.8s
# 513:	learn: 0.5574467	total: 13.5s	remaining: 12.7s
# 514:	learn: 0.5573621	total: 13.5s	remaining: 12.7s
# 515:	learn: 0.5573061	total: 13.5s	remaining: 12.7s
# 516:	learn: 0.5572165	total: 13.5s	remaining: 12.7s
# 517:	learn: 0.5571472	total: 13.6s	remaining: 12.6s
# 518:	learn: 0.5570734	total: 13.6s	remaining: 12.6s
# 519:	learn: 0.5570438	total: 13.6s	remaining: 12.6s
# 520:	learn: 0.5570162	total: 13.6s	remaining: 12.5s
# 521:	learn: 0.5569607	total: 13.7s	remaining: 12.5s
# 522:	learn: 0.5568599	total: 13.7s	remaining: 12.5s
# 523:	learn: 0.5567960	total: 13.7s	remaining: 12.5s
# 524:	learn: 0.5566956	total: 13.7s	remaining: 12.4s
# 525:	learn: 0.5566339	total: 13.8s	remaining: 12.4s
# 526:	learn: 0.5565374	total: 13.8s	remaining: 12.4s
# 527:	learn: 0.5562390	total: 13.8s	remaining: 12.4s
# 528:	learn: 0.5560714	total: 13.8s	remaining: 12.3s
# 529:	learn: 0.5559270	total: 13.9s	remaining: 12.3s
# 530:	learn: 0.5558763	total: 13.9s	remaining: 12.3s
# 531:	learn: 0.5558546	total: 13.9s	remaining: 12.3s
# 532:	learn: 0.5558122	total: 14s	remaining: 12.2s
# 533:	learn: 0.5557523	total: 14s	remaining: 12.2s
# 534:	learn: 0.5557167	total: 14s	remaining: 12.2s
# 535:	learn: 0.5554314	total: 14s	remaining: 12.2s
# 536:	learn: 0.5552573	total: 14.1s	remaining: 12.1s
# 537:	learn: 0.5552326	total: 14.1s	remaining: 12.1s
# 538:	learn: 0.5550451	total: 14.1s	remaining: 12.1s
# 539:	learn: 0.5550254	total: 14.1s	remaining: 12.1s
# 540:	learn: 0.5548702	total: 14.2s	remaining: 12s
# 541:	learn: 0.5548265	total: 14.2s	remaining: 12s
# 542:	learn: 0.5548140	total: 14.3s	remaining: 12s
# 543:	learn: 0.5545143	total: 14.3s	remaining: 12s
# 544:	learn: 0.5544424	total: 14.4s	remaining: 12s
# 545:	learn: 0.5541837	total: 14.4s	remaining: 12s
# 546:	learn: 0.5540743	total: 14.4s	remaining: 12s
# 547:	learn: 0.5540336	total: 14.5s	remaining: 12s
# 548:	learn: 0.5540176	total: 14.5s	remaining: 11.9s
# 549:	learn: 0.5540078	total: 14.6s	remaining: 11.9s
# 550:	learn: 0.5539330	total: 14.6s	remaining: 11.9s
# 551:	learn: 0.5537668	total: 14.6s	remaining: 11.9s
# 552:	learn: 0.5537463	total: 14.7s	remaining: 11.8s
# 553:	learn: 0.5536707	total: 14.7s	remaining: 11.8s
# 554:	learn: 0.5536483	total: 14.7s	remaining: 11.8s
# 555:	learn: 0.5535341	total: 14.8s	remaining: 11.8s
# 556:	learn: 0.5533638	total: 14.8s	remaining: 11.8s
# 557:	learn: 0.5532094	total: 14.8s	remaining: 11.7s
# 558:	learn: 0.5530658	total: 14.8s	remaining: 11.7s
# 559:	learn: 0.5530140	total: 14.9s	remaining: 11.7s
# 560:	learn: 0.5526953	total: 14.9s	remaining: 11.7s
# 561:	learn: 0.5525310	total: 14.9s	remaining: 11.6s
# 562:	learn: 0.5524270	total: 14.9s	remaining: 11.6s
# 563:	learn: 0.5523287	total: 15s	remaining: 11.6s
# 564:	learn: 0.5521204	total: 15s	remaining: 11.5s
# 565:	learn: 0.5520785	total: 15s	remaining: 11.5s
# 566:	learn: 0.5518852	total: 15.1s	remaining: 11.5s
# 567:	learn: 0.5518162	total: 15.1s	remaining: 11.5s
# 568:	learn: 0.5516921	total: 15.1s	remaining: 11.4s
# 569:	learn: 0.5515938	total: 15.1s	remaining: 11.4s
# 570:	learn: 0.5515713	total: 15.2s	remaining: 11.4s
# 571:	learn: 0.5514432	total: 15.2s	remaining: 11.4s
# 572:	learn: 0.5513711	total: 15.2s	remaining: 11.3s
# 573:	learn: 0.5511978	total: 15.2s	remaining: 11.3s
# 574:	learn: 0.5510940	total: 15.3s	remaining: 11.3s
# 575:	learn: 0.5510377	total: 15.3s	remaining: 11.3s
# 576:	learn: 0.5509641	total: 15.3s	remaining: 11.2s
# 577:	learn: 0.5508664	total: 15.3s	remaining: 11.2s
# 578:	learn: 0.5508462	total: 15.4s	remaining: 11.2s
# 579:	learn: 0.5508054	total: 15.4s	remaining: 11.1s
# 580:	learn: 0.5505373	total: 15.4s	remaining: 11.1s
# 581:	learn: 0.5504346	total: 15.4s	remaining: 11.1s
# 582:	learn: 0.5504251	total: 15.5s	remaining: 11.1s
# 583:	learn: 0.5503215	total: 15.5s	remaining: 11s
# 584:	learn: 0.5502503	total: 15.5s	remaining: 11s
# 585:	learn: 0.5501356	total: 15.6s	remaining: 11s
# 586:	learn: 0.5500894	total: 15.6s	remaining: 11s
# 587:	learn: 0.5500513	total: 15.6s	remaining: 10.9s
# 588:	learn: 0.5498339	total: 15.6s	remaining: 10.9s
# 589:	learn: 0.5497559	total: 15.7s	remaining: 10.9s
# 590:	learn: 0.5496299	total: 15.7s	remaining: 10.9s
# 591:	learn: 0.5496214	total: 15.7s	remaining: 10.8s
# 592:	learn: 0.5495623	total: 15.7s	remaining: 10.8s
# 593:	learn: 0.5494014	total: 15.8s	remaining: 10.8s
# 594:	learn: 0.5493738	total: 15.8s	remaining: 10.8s
# 595:	learn: 0.5490183	total: 15.9s	remaining: 10.7s
# 596:	learn: 0.5489817	total: 15.9s	remaining: 10.7s
# 597:	learn: 0.5489384	total: 15.9s	remaining: 10.7s
# 598:	learn: 0.5489186	total: 16s	remaining: 10.7s
# 599:	learn: 0.5488665	total: 16s	remaining: 10.7s
# 600:	learn: 0.5487867	total: 16s	remaining: 10.6s
# 601:	learn: 0.5486878	total: 16s	remaining: 10.6s
# 602:	learn: 0.5486366	total: 16.1s	remaining: 10.6s
# 603:	learn: 0.5483226	total: 16.1s	remaining: 10.5s
# 604:	learn: 0.5480639	total: 16.1s	remaining: 10.5s
# 605:	learn: 0.5479494	total: 16.1s	remaining: 10.5s
# 606:	learn: 0.5477493	total: 16.1s	remaining: 10.5s
# 607:	learn: 0.5474385	total: 16.2s	remaining: 10.4s
# 608:	learn: 0.5473723	total: 16.2s	remaining: 10.4s
# 609:	learn: 0.5473508	total: 16.2s	remaining: 10.4s
# 610:	learn: 0.5472708	total: 16.2s	remaining: 10.3s
# 611:	learn: 0.5471112	total: 16.3s	remaining: 10.3s
# 612:	learn: 0.5467681	total: 16.3s	remaining: 10.3s
# 613:	learn: 0.5467623	total: 16.3s	remaining: 10.3s
# 614:	learn: 0.5466088	total: 16.3s	remaining: 10.2s
# 615:	learn: 0.5465774	total: 16.4s	remaining: 10.2s
# 616:	learn: 0.5465722	total: 16.4s	remaining: 10.2s
# 617:	learn: 0.5463567	total: 16.4s	remaining: 10.1s
# 618:	learn: 0.5460954	total: 16.4s	remaining: 10.1s
# 619:	learn: 0.5460815	total: 16.5s	remaining: 10.1s
# 620:	learn: 0.5460135	total: 16.5s	remaining: 10.1s
# 621:	learn: 0.5459380	total: 16.5s	remaining: 10.1s
# 622:	learn: 0.5458687	total: 16.6s	remaining: 10s
# 623:	learn: 0.5456568	total: 16.7s	remaining: 10s
# 624:	learn: 0.5454111	total: 16.7s	remaining: 10s
# 625:	learn: 0.5453213	total: 16.7s	remaining: 10s
# 626:	learn: 0.5452484	total: 16.8s	remaining: 9.97s
# 627:	learn: 0.5452210	total: 16.8s	remaining: 9.94s
# 628:	learn: 0.5452144	total: 16.8s	remaining: 9.92s
# 629:	learn: 0.5450374	total: 16.8s	remaining: 9.89s
# 630:	learn: 0.5449217	total: 16.9s	remaining: 9.86s
# 631:	learn: 0.5447453	total: 16.9s	remaining: 9.84s
# 632:	learn: 0.5446760	total: 16.9s	remaining: 9.81s
# 633:	learn: 0.5445370	total: 16.9s	remaining: 9.78s
# 634:	learn: 0.5444708	total: 17s	remaining: 9.76s
# 635:	learn: 0.5443917	total: 17s	remaining: 9.73s
# 636:	learn: 0.5441472	total: 17s	remaining: 9.71s
# 637:	learn: 0.5441136	total: 17.1s	remaining: 9.68s
# 638:	learn: 0.5441040	total: 17.1s	remaining: 9.65s
# 639:	learn: 0.5440979	total: 17.1s	remaining: 9.62s
# 640:	learn: 0.5439747	total: 17.1s	remaining: 9.59s
# 641:	learn: 0.5438176	total: 17.2s	remaining: 9.57s
# 642:	learn: 0.5437835	total: 17.2s	remaining: 9.54s
# 643:	learn: 0.5437444	total: 17.2s	remaining: 9.51s
# 644:	learn: 0.5436865	total: 17.2s	remaining: 9.48s
# 645:	learn: 0.5435862	total: 17.3s	remaining: 9.45s
# 646:	learn: 0.5435813	total: 17.3s	remaining: 9.43s
# 647:	learn: 0.5435411	total: 17.3s	remaining: 9.4s
# 648:	learn: 0.5434358	total: 17.3s	remaining: 9.37s
# 649:	learn: 0.5434156	total: 17.3s	remaining: 9.34s
# 650:	learn: 0.5433582	total: 17.4s	remaining: 9.31s
# 651:	learn: 0.5432403	total: 17.4s	remaining: 9.28s
# 652:	learn: 0.5431493	total: 17.4s	remaining: 9.25s
# 653:	learn: 0.5429732	total: 17.4s	remaining: 9.23s
# 654:	learn: 0.5429031	total: 17.5s	remaining: 9.2s
# 655:	learn: 0.5427368	total: 17.5s	remaining: 9.17s
# 656:	learn: 0.5425324	total: 17.5s	remaining: 9.14s
# 657:	learn: 0.5424496	total: 17.5s	remaining: 9.11s
# 658:	learn: 0.5423441	total: 17.6s	remaining: 9.08s
# 659:	learn: 0.5422374	total: 17.6s	remaining: 9.05s
# 660:	learn: 0.5421773	total: 17.6s	remaining: 9.03s
# 661:	learn: 0.5420993	total: 17.6s	remaining: 8.99s
# 662:	learn: 0.5418406	total: 17.6s	remaining: 8.97s
# 663:	learn: 0.5417372	total: 17.7s	remaining: 8.94s
# 664:	learn: 0.5417312	total: 17.7s	remaining: 8.91s
# 665:	learn: 0.5417136	total: 17.7s	remaining: 8.88s
# 666:	learn: 0.5416493	total: 17.7s	remaining: 8.85s
# 667:	learn: 0.5414737	total: 17.8s	remaining: 8.82s
# 668:	learn: 0.5414673	total: 17.8s	remaining: 8.79s
# 669:	learn: 0.5414576	total: 17.8s	remaining: 8.76s
# 670:	learn: 0.5412685	total: 17.8s	remaining: 8.74s
# 671:	learn: 0.5412258	total: 17.8s	remaining: 8.71s
# 672:	learn: 0.5409681	total: 17.9s	remaining: 8.68s
# 673:	learn: 0.5408375	total: 17.9s	remaining: 8.65s
# 674:	learn: 0.5406140	total: 17.9s	remaining: 8.63s
# 675:	learn: 0.5404781	total: 17.9s	remaining: 8.6s
# 676:	learn: 0.5404663	total: 18s	remaining: 8.57s
# 677:	learn: 0.5404210	total: 18s	remaining: 8.54s
# 678:	learn: 0.5402554	total: 18s	remaining: 8.51s
# 679:	learn: 0.5402449	total: 18s	remaining: 8.48s
# 680:	learn: 0.5401416	total: 18s	remaining: 8.45s
# 681:	learn: 0.5400242	total: 18.1s	remaining: 8.42s
# 682:	learn: 0.5399457	total: 18.1s	remaining: 8.39s
# 683:	learn: 0.5398944	total: 18.1s	remaining: 8.36s
# 684:	learn: 0.5397940	total: 18.1s	remaining: 8.34s
# 685:	learn: 0.5396660	total: 18.2s	remaining: 8.31s
# 686:	learn: 0.5394434	total: 18.2s	remaining: 8.28s
# 687:	learn: 0.5394378	total: 18.2s	remaining: 8.25s
# 688:	learn: 0.5393510	total: 18.2s	remaining: 8.22s
# 689:	learn: 0.5392706	total: 18.2s	remaining: 8.19s
# 690:	learn: 0.5392565	total: 18.3s	remaining: 8.16s
# 691:	learn: 0.5391740	total: 18.3s	remaining: 8.14s
# 692:	learn: 0.5391349	total: 18.3s	remaining: 8.11s
# 693:	learn: 0.5390083	total: 18.3s	remaining: 8.08s
# 694:	learn: 0.5389092	total: 18.4s	remaining: 8.05s
# 695:	learn: 0.5389044	total: 18.4s	remaining: 8.03s
# 696:	learn: 0.5388306	total: 18.4s	remaining: 8s
# 697:	learn: 0.5387833	total: 18.4s	remaining: 7.97s
# 698:	learn: 0.5387241	total: 18.5s	remaining: 7.95s
# 699:	learn: 0.5386824	total: 18.5s	remaining: 7.92s
# 700:	learn: 0.5385633	total: 18.5s	remaining: 7.89s
# 701:	learn: 0.5383164	total: 18.5s	remaining: 7.86s
# 702:	learn: 0.5382089	total: 18.6s	remaining: 7.84s
# 703:	learn: 0.5381964	total: 18.6s	remaining: 7.81s
# 704:	learn: 0.5381385	total: 18.6s	remaining: 7.78s
# 705:	learn: 0.5380509	total: 18.6s	remaining: 7.75s
# 706:	learn: 0.5378440	total: 18.6s	remaining: 7.72s
# 707:	learn: 0.5377806	total: 18.7s	remaining: 7.7s
# 708:	learn: 0.5376564	total: 18.7s	remaining: 7.67s
# 709:	learn: 0.5374276	total: 18.7s	remaining: 7.64s
# 710:	learn: 0.5372444	total: 18.7s	remaining: 7.61s
# 711:	learn: 0.5370010	total: 18.8s	remaining: 7.59s
# 712:	learn: 0.5369751	total: 18.8s	remaining: 7.56s
# 713:	learn: 0.5368815	total: 18.8s	remaining: 7.53s
# 714:	learn: 0.5367708	total: 18.8s	remaining: 7.5s
# 715:	learn: 0.5366796	total: 18.8s	remaining: 7.47s
# 716:	learn: 0.5365845	total: 18.9s	remaining: 7.45s
# 717:	learn: 0.5365731	total: 18.9s	remaining: 7.42s
# 718:	learn: 0.5364299	total: 18.9s	remaining: 7.39s
# 719:	learn: 0.5363095	total: 18.9s	remaining: 7.36s
# 720:	learn: 0.5361696	total: 19s	remaining: 7.33s
# 721:	learn: 0.5361232	total: 19s	remaining: 7.31s
# 722:	learn: 0.5359779	total: 19s	remaining: 7.28s
# 723:	learn: 0.5358272	total: 19s	remaining: 7.25s
# 724:	learn: 0.5357394	total: 19s	remaining: 7.22s
# 725:	learn: 0.5355910	total: 19.1s	remaining: 7.2s
# 726:	learn: 0.5355030	total: 19.1s	remaining: 7.17s
# 727:	learn: 0.5352497	total: 19.1s	remaining: 7.14s
# 728:	learn: 0.5349811	total: 19.1s	remaining: 7.12s
# 729:	learn: 0.5348284	total: 19.2s	remaining: 7.09s
# 730:	learn: 0.5347461	total: 19.2s	remaining: 7.06s
# 731:	learn: 0.5346053	total: 19.2s	remaining: 7.04s
# 732:	learn: 0.5344345	total: 19.2s	remaining: 7.01s
# 733:	learn: 0.5341764	total: 19.3s	remaining: 6.98s
# 734:	learn: 0.5340632	total: 19.3s	remaining: 6.95s
# 735:	learn: 0.5339110	total: 19.3s	remaining: 6.93s
# 736:	learn: 0.5336394	total: 19.3s	remaining: 6.9s
# 737:	learn: 0.5333693	total: 19.4s	remaining: 6.87s
# 738:	learn: 0.5332174	total: 19.4s	remaining: 6.84s
# 739:	learn: 0.5332021	total: 19.4s	remaining: 6.82s
# 740:	learn: 0.5331915	total: 19.4s	remaining: 6.79s
# 741:	learn: 0.5331158	total: 19.5s	remaining: 6.77s
# 742:	learn: 0.5329872	total: 19.5s	remaining: 6.74s
# 743:	learn: 0.5329577	total: 19.5s	remaining: 6.72s
# 744:	learn: 0.5329494	total: 19.6s	remaining: 6.7s
# 745:	learn: 0.5329180	total: 19.6s	remaining: 6.67s
# 746:	learn: 0.5328100	total: 19.6s	remaining: 6.65s
# 747:	learn: 0.5326895	total: 19.7s	remaining: 6.62s
# 748:	learn: 0.5324366	total: 19.7s	remaining: 6.6s
# 749:	learn: 0.5323478	total: 19.7s	remaining: 6.58s
# 750:	learn: 0.5323015	total: 19.8s	remaining: 6.55s
# 751:	learn: 0.5321528	total: 19.8s	remaining: 6.53s
# 752:	learn: 0.5320509	total: 19.8s	remaining: 6.5s
# 753:	learn: 0.5320398	total: 19.9s	remaining: 6.48s
# 754:	learn: 0.5320263	total: 19.9s	remaining: 6.45s
# 755:	learn: 0.5320042	total: 19.9s	remaining: 6.42s
# 756:	learn: 0.5319540	total: 19.9s	remaining: 6.39s
# 757:	learn: 0.5318814	total: 19.9s	remaining: 6.37s
# 758:	learn: 0.5318453	total: 20s	remaining: 6.36s
# 759:	learn: 0.5317369	total: 20.1s	remaining: 6.33s
# 760:	learn: 0.5316899	total: 20.1s	remaining: 6.31s
# 761:	learn: 0.5316853	total: 20.1s	remaining: 6.28s
# 762:	learn: 0.5315052	total: 20.2s	remaining: 6.26s
# 763:	learn: 0.5314212	total: 20.2s	remaining: 6.23s
# 764:	learn: 0.5313969	total: 20.2s	remaining: 6.21s
# 765:	learn: 0.5313879	total: 20.2s	remaining: 6.18s
# 766:	learn: 0.5313810	total: 20.3s	remaining: 6.16s
# 767:	learn: 0.5311215	total: 20.3s	remaining: 6.14s
# 768:	learn: 0.5307859	total: 20.8s	remaining: 6.25s
# 769:	learn: 0.5306923	total: 20.9s	remaining: 6.25s
# 770:	learn: 0.5305874	total: 21s	remaining: 6.22s
# 771:	learn: 0.5303366	total: 21.1s	remaining: 6.24s
# 772:	learn: 0.5300091	total: 21.2s	remaining: 6.23s
# 773:	learn: 0.5299078	total: 21.2s	remaining: 6.2s
# 774:	learn: 0.5297478	total: 21.3s	remaining: 6.18s
# 775:	learn: 0.5295911	total: 21.3s	remaining: 6.15s
# 776:	learn: 0.5295035	total: 21.3s	remaining: 6.12s
# 777:	learn: 0.5294516	total: 21.4s	remaining: 6.1s
# 778:	learn: 0.5291593	total: 21.4s	remaining: 6.07s
# 779:	learn: 0.5289698	total: 21.4s	remaining: 6.05s
# 780:	learn: 0.5289564	total: 21.5s	remaining: 6.02s
# 781:	learn: 0.5287778	total: 21.5s	remaining: 6s
# 782:	learn: 0.5286048	total: 21.5s	remaining: 5.97s
# 783:	learn: 0.5284253	total: 21.6s	remaining: 5.94s
# 784:	learn: 0.5281568	total: 21.6s	remaining: 5.92s
# 785:	learn: 0.5279607	total: 21.6s	remaining: 5.89s
# 786:	learn: 0.5277317	total: 21.7s	remaining: 5.86s
# 787:	learn: 0.5276905	total: 21.7s	remaining: 5.83s
# 788:	learn: 0.5276563	total: 21.7s	remaining: 5.81s
# 789:	learn: 0.5275658	total: 21.7s	remaining: 5.78s
# 790:	learn: 0.5274173	total: 21.8s	remaining: 5.75s
# 791:	learn: 0.5272832	total: 21.8s	remaining: 5.72s
# 792:	learn: 0.5271674	total: 21.8s	remaining: 5.69s
# 793:	learn: 0.5270580	total: 21.8s	remaining: 5.67s
# 794:	learn: 0.5270291	total: 21.9s	remaining: 5.64s
# 795:	learn: 0.5269822	total: 21.9s	remaining: 5.61s
# 796:	learn: 0.5268952	total: 21.9s	remaining: 5.58s
# 797:	learn: 0.5268747	total: 21.9s	remaining: 5.55s
# 798:	learn: 0.5268503	total: 22s	remaining: 5.53s
# 799:	learn: 0.5267077	total: 22s	remaining: 5.5s
# 800:	learn: 0.5266045	total: 22s	remaining: 5.47s
# 801:	learn: 0.5265173	total: 22s	remaining: 5.44s
# 802:	learn: 0.5264385	total: 22.1s	remaining: 5.41s
# 803:	learn: 0.5264014	total: 22.1s	remaining: 5.38s
# 804:	learn: 0.5262308	total: 22.1s	remaining: 5.36s
# 805:	learn: 0.5260880	total: 22.1s	remaining: 5.33s
# 806:	learn: 0.5260828	total: 22.2s	remaining: 5.3s
# 807:	learn: 0.5259764	total: 22.2s	remaining: 5.27s
# 808:	learn: 0.5258975	total: 22.2s	remaining: 5.25s
# 809:	learn: 0.5257499	total: 22.2s	remaining: 5.22s
# 810:	learn: 0.5256651	total: 22.3s	remaining: 5.19s
# 811:	learn: 0.5256060	total: 22.3s	remaining: 5.16s
# 812:	learn: 0.5255768	total: 22.3s	remaining: 5.13s
# 813:	learn: 0.5254449	total: 22.3s	remaining: 5.1s
# 814:	learn: 0.5252941	total: 22.4s	remaining: 5.08s
# 815:	learn: 0.5252595	total: 22.4s	remaining: 5.05s
# 816:	learn: 0.5252487	total: 22.4s	remaining: 5.02s
# 817:	learn: 0.5251718	total: 22.4s	remaining: 4.99s
# 818:	learn: 0.5250239	total: 22.5s	remaining: 4.96s
# 819:	learn: 0.5249604	total: 22.5s	remaining: 4.93s
# 820:	learn: 0.5249260	total: 22.5s	remaining: 4.91s
# 821:	learn: 0.5248832	total: 22.5s	remaining: 4.88s
# 822:	learn: 0.5247329	total: 22.6s	remaining: 4.85s
# 823:	learn: 0.5246917	total: 22.6s	remaining: 4.83s
# 824:	learn: 0.5246088	total: 22.6s	remaining: 4.8s
# 825:	learn: 0.5244686	total: 22.7s	remaining: 4.77s
# 826:	learn: 0.5243313	total: 22.7s	remaining: 4.75s
# 827:	learn: 0.5241180	total: 22.7s	remaining: 4.72s
# 828:	learn: 0.5240346	total: 22.7s	remaining: 4.69s
# 829:	learn: 0.5238535	total: 22.8s	remaining: 4.66s
# 830:	learn: 0.5238410	total: 22.8s	remaining: 4.63s
# 831:	learn: 0.5237129	total: 22.8s	remaining: 4.61s
# 832:	learn: 0.5236142	total: 22.8s	remaining: 4.58s
# 833:	learn: 0.5235475	total: 22.9s	remaining: 4.55s
# 834:	learn: 0.5233797	total: 22.9s	remaining: 4.52s
# 835:	learn: 0.5233634	total: 22.9s	remaining: 4.49s
# 836:	learn: 0.5231880	total: 22.9s	remaining: 4.47s
# 837:	learn: 0.5229344	total: 23s	remaining: 4.44s
# 838:	learn: 0.5227650	total: 23s	remaining: 4.41s
# 839:	learn: 0.5227037	total: 23s	remaining: 4.38s
# 840:	learn: 0.5226466	total: 23s	remaining: 4.36s
# 841:	learn: 0.5225958	total: 23.1s	remaining: 4.33s
# 842:	learn: 0.5224821	total: 23.1s	remaining: 4.3s
# 843:	learn: 0.5224490	total: 23.1s	remaining: 4.27s
# 844:	learn: 0.5224034	total: 23.1s	remaining: 4.24s
# 845:	learn: 0.5222664	total: 23.2s	remaining: 4.22s
# 846:	learn: 0.5221330	total: 23.2s	remaining: 4.19s
# 847:	learn: 0.5220303	total: 23.2s	remaining: 4.16s
# 848:	learn: 0.5219347	total: 23.2s	remaining: 4.13s
# 849:	learn: 0.5218984	total: 23.3s	remaining: 4.11s
# 850:	learn: 0.5218490	total: 23.3s	remaining: 4.08s
# 851:	learn: 0.5217660	total: 23.3s	remaining: 4.05s
# 852:	learn: 0.5217246	total: 23.3s	remaining: 4.02s
# 853:	learn: 0.5214797	total: 23.4s	remaining: 4s
# 854:	learn: 0.5212144	total: 23.4s	remaining: 3.97s
# 855:	learn: 0.5211289	total: 23.4s	remaining: 3.94s
# 856:	learn: 0.5211164	total: 23.5s	remaining: 3.91s
# 857:	learn: 0.5210874	total: 23.5s	remaining: 3.88s
# 858:	learn: 0.5209436	total: 23.5s	remaining: 3.86s
# 859:	learn: 0.5208873	total: 23.5s	remaining: 3.83s
# 860:	learn: 0.5207431	total: 23.6s	remaining: 3.8s
# 861:	learn: 0.5206475	total: 23.6s	remaining: 3.77s
# 862:	learn: 0.5206283	total: 23.6s	remaining: 3.75s
# 863:	learn: 0.5204973	total: 23.6s	remaining: 3.72s
# 864:	learn: 0.5204535	total: 23.7s	remaining: 3.69s
# 865:	learn: 0.5203678	total: 23.7s	remaining: 3.67s
# 866:	learn: 0.5203275	total: 23.7s	remaining: 3.64s
# 867:	learn: 0.5203206	total: 23.8s	remaining: 3.61s
# 868:	learn: 0.5202563	total: 23.8s	remaining: 3.58s
# 869:	learn: 0.5200877	total: 23.8s	remaining: 3.56s
# 870:	learn: 0.5199953	total: 23.8s	remaining: 3.53s
# 871:	learn: 0.5198698	total: 23.9s	remaining: 3.5s
# 872:	learn: 0.5198427	total: 23.9s	remaining: 3.47s
# 873:	learn: 0.5198258	total: 23.9s	remaining: 3.45s
# 874:	learn: 0.5196244	total: 23.9s	remaining: 3.42s
# 875:	learn: 0.5195628	total: 24s	remaining: 3.39s
# 876:	learn: 0.5194431	total: 24s	remaining: 3.37s
# 877:	learn: 0.5193702	total: 24s	remaining: 3.34s
# 878:	learn: 0.5193234	total: 24.1s	remaining: 3.31s
# 879:	learn: 0.5192676	total: 24.1s	remaining: 3.28s
# 880:	learn: 0.5191217	total: 24.1s	remaining: 3.25s
# 881:	learn: 0.5190071	total: 24.1s	remaining: 3.23s
# 882:	learn: 0.5188455	total: 24.2s	remaining: 3.2s
# 883:	learn: 0.5188413	total: 24.2s	remaining: 3.17s
# 884:	learn: 0.5187356	total: 24.2s	remaining: 3.14s
# 885:	learn: 0.5187151	total: 24.2s	remaining: 3.12s
# 886:	learn: 0.5186557	total: 24.2s	remaining: 3.09s
# 887:	learn: 0.5186495	total: 24.3s	remaining: 3.06s
# 888:	learn: 0.5185242	total: 24.3s	remaining: 3.03s
# 889:	learn: 0.5184656	total: 24.3s	remaining: 3s
# 890:	learn: 0.5184024	total: 24.4s	remaining: 2.98s
# 891:	learn: 0.5183596	total: 24.4s	remaining: 2.95s
# 892:	learn: 0.5183218	total: 24.4s	remaining: 2.92s
# 893:	learn: 0.5181737	total: 24.4s	remaining: 2.9s
# 894:	learn: 0.5181547	total: 24.5s	remaining: 2.87s
# 895:	learn: 0.5180595	total: 24.5s	remaining: 2.84s
# 896:	learn: 0.5180552	total: 24.5s	remaining: 2.81s
# 897:	learn: 0.5180171	total: 24.5s	remaining: 2.79s
# 898:	learn: 0.5178892	total: 24.5s	remaining: 2.76s
# 899:	learn: 0.5177314	total: 24.6s	remaining: 2.73s
# 900:	learn: 0.5174851	total: 24.6s	remaining: 2.7s
# 901:	learn: 0.5174504	total: 24.6s	remaining: 2.68s
# 902:	learn: 0.5173907	total: 24.7s	remaining: 2.65s
# 903:	learn: 0.5173048	total: 24.7s	remaining: 2.62s
# 904:	learn: 0.5171179	total: 24.7s	remaining: 2.59s
# 905:	learn: 0.5170693	total: 24.7s	remaining: 2.56s
# 906:	learn: 0.5168902	total: 24.7s	remaining: 2.54s
# 907:	learn: 0.5168100	total: 24.8s	remaining: 2.51s
# 908:	learn: 0.5164701	total: 24.8s	remaining: 2.48s
# 909:	learn: 0.5164415	total: 24.8s	remaining: 2.45s
# 910:	learn: 0.5161366	total: 24.8s	remaining: 2.43s
# 911:	learn: 0.5160372	total: 24.9s	remaining: 2.4s
# 912:	learn: 0.5158654	total: 24.9s	remaining: 2.37s
# 913:	learn: 0.5157458	total: 24.9s	remaining: 2.34s
# 914:	learn: 0.5156937	total: 24.9s	remaining: 2.32s
# 915:	learn: 0.5155792	total: 25s	remaining: 2.29s
# 916:	learn: 0.5153353	total: 25s	remaining: 2.26s
# 917:	learn: 0.5151589	total: 25s	remaining: 2.23s
# 918:	learn: 0.5149638	total: 25s	remaining: 2.21s
# 919:	learn: 0.5147906	total: 25.1s	remaining: 2.18s
# 920:	learn: 0.5145562	total: 25.1s	remaining: 2.15s
# 921:	learn: 0.5144421	total: 25.1s	remaining: 2.12s
# 922:	learn: 0.5144005	total: 25.1s	remaining: 2.1s
# 923:	learn: 0.5141703	total: 25.2s	remaining: 2.07s
# 924:	learn: 0.5141427	total: 25.2s	remaining: 2.04s
# 925:	learn: 0.5140730	total: 25.2s	remaining: 2.02s
# 926:	learn: 0.5139853	total: 25.2s	remaining: 1.99s
# 927:	learn: 0.5137310	total: 25.3s	remaining: 1.96s
# 928:	learn: 0.5136400	total: 25.3s	remaining: 1.93s
# 929:	learn: 0.5135113	total: 25.3s	remaining: 1.91s
# 930:	learn: 0.5132368	total: 25.3s	remaining: 1.88s
# 931:	learn: 0.5129594	total: 25.4s	remaining: 1.85s
# 932:	learn: 0.5128858	total: 25.4s	remaining: 1.82s
# 933:	learn: 0.5127197	total: 25.4s	remaining: 1.8s
# 934:	learn: 0.5126771	total: 25.5s	remaining: 1.77s
# 935:	learn: 0.5126316	total: 25.5s	remaining: 1.74s
# 936:	learn: 0.5126000	total: 25.5s	remaining: 1.71s
# 937:	learn: 0.5123511	total: 25.6s	remaining: 1.69s
# 938:	learn: 0.5122910	total: 25.6s	remaining: 1.66s
# 939:	learn: 0.5122730	total: 25.6s	remaining: 1.63s
# 940:	learn: 0.5120850	total: 25.6s	remaining: 1.61s
# 941:	learn: 0.5119956	total: 25.7s	remaining: 1.58s
# 942:	learn: 0.5118652	total: 25.7s	remaining: 1.55s
# 943:	learn: 0.5116696	total: 25.7s	remaining: 1.53s
# 944:	learn: 0.5114550	total: 25.8s	remaining: 1.5s
# 945:	learn: 0.5112209	total: 25.8s	remaining: 1.47s
# 946:	learn: 0.5111422	total: 25.8s	remaining: 1.45s
# 947:	learn: 0.5110177	total: 25.9s	remaining: 1.42s
# 948:	learn: 0.5107996	total: 25.9s	remaining: 1.39s
# 949:	learn: 0.5107231	total: 25.9s	remaining: 1.36s
# 950:	learn: 0.5106942	total: 25.9s	remaining: 1.34s
# 951:	learn: 0.5106166	total: 26s	remaining: 1.31s
# 952:	learn: 0.5104493	total: 26s	remaining: 1.28s
# 953:	learn: 0.5102231	total: 26s	remaining: 1.25s
# 954:	learn: 0.5100326	total: 26.1s	remaining: 1.23s
# 955:	learn: 0.5099702	total: 26.1s	remaining: 1.2s
# 956:	learn: 0.5098013	total: 26.1s	remaining: 1.17s
# 957:	learn: 0.5097130	total: 26.2s	remaining: 1.15s
# 958:	learn: 0.5096797	total: 26.2s	remaining: 1.12s
# 959:	learn: 0.5096677	total: 26.2s	remaining: 1.09s
# 960:	learn: 0.5094680	total: 26.2s	remaining: 1.06s
# 961:	learn: 0.5092467	total: 26.3s	remaining: 1.04s
# 962:	learn: 0.5092341	total: 26.3s	remaining: 1.01s
# 963:	learn: 0.5091806	total: 26.3s	remaining: 983ms
# 964:	learn: 0.5087632	total: 26.4s	remaining: 956ms
# 965:	learn: 0.5086039	total: 26.4s	remaining: 929ms
# 966:	learn: 0.5084378	total: 26.4s	remaining: 901ms
# 967:	learn: 0.5082664	total: 26.4s	remaining: 874ms
# 968:	learn: 0.5081991	total: 26.5s	remaining: 847ms
# 969:	learn: 0.5080197	total: 26.5s	remaining: 820ms
# 970:	learn: 0.5079038	total: 26.5s	remaining: 793ms
# 971:	learn: 0.5078495	total: 26.6s	remaining: 766ms
# 972:	learn: 0.5077142	total: 26.6s	remaining: 738ms
# 973:	learn: 0.5076460	total: 26.6s	remaining: 711ms
# 974:	learn: 0.5072771	total: 26.7s	remaining: 684ms
# 975:	learn: 0.5071873	total: 26.7s	remaining: 656ms
# 976:	learn: 0.5070123	total: 26.7s	remaining: 629ms
# 977:	learn: 0.5069387	total: 26.8s	remaining: 602ms
# 978:	learn: 0.5068553	total: 26.8s	remaining: 575ms
# 979:	learn: 0.5068238	total: 26.8s	remaining: 548ms
# 980:	learn: 0.5067560	total: 26.9s	remaining: 520ms
# 981:	learn: 0.5066044	total: 26.9s	remaining: 493ms
# 982:	learn: 0.5065912	total: 26.9s	remaining: 465ms
# 983:	learn: 0.5064355	total: 26.9s	remaining: 438ms
# 984:	learn: 0.5063588	total: 27s	remaining: 411ms
# 985:	learn: 0.5063142	total: 27s	remaining: 383ms
# 986:	learn: 0.5061928	total: 27s	remaining: 356ms
# 987:	learn: 0.5061155	total: 27s	remaining: 329ms
# 988:	learn: 0.5060856	total: 27.1s	remaining: 301ms
# 989:	learn: 0.5060794	total: 27.1s	remaining: 274ms
# 990:	learn: 0.5060123	total: 27.1s	remaining: 246ms
# 991:	learn: 0.5059012	total: 27.1s	remaining: 219ms
# 992:	learn: 0.5058270	total: 27.2s	remaining: 191ms
# 993:	learn: 0.5058204	total: 27.2s	remaining: 164ms
# 994:	learn: 0.5054537	total: 27.2s	remaining: 137ms
# 995:	learn: 0.5053516	total: 27.2s	remaining: 109ms
# 996:	learn: 0.5051897	total: 27.3s	remaining: 82ms
# 997:	learn: 0.5051351	total: 27.3s	remaining: 54.7ms
# 998:	learn: 0.5050862	total: 27.3s	remaining: 27.3ms
# 999:	learn: 0.5048389	total: 27.3s	remaining: 0us

# %%
y_pred = clf.predict(sparse_data_test)

# %%
bas = balanced_accuracy_score(clean_data_test['average_bill'], y_pred)
bas
# Out:
# 0.35498588639726775
